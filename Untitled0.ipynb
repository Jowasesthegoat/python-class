# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-class/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nice to meet you my name is joses",)
print("My age is-",11)
print("My favorite sport is soccer")
print("My favorite food is pizza")
# Out:
# Nice to meet you my name is joses
# My age is- 11
# My favorite sport is soccer
# My favorite food is pizza

# %%
name = "Joses Adejuyigbe"
print(f"my name is {name}")
score=17
print(f"my score is {score}")
yourname=input("what is your name?")
print(f"hello {yourname}")
yourscore=input("what was your score?")
print(f"wow {yourscore} that was good! ")
# Out:
# my name is Joses Adejuyigbe
# my score is 17
# what is your name?17
# hello 17
# what was your score?17
# wow 17 that was good!

# %%
import keyword
print(f"keywords in python are- {keyword.kwlist}")
# Out:
# keywords in python are- ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
