# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-class/blob/main/python_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to my quiz!")
score=0
print()
print("how many edges does a cube have?")
print("A.8")
print("B.12")
print("C.16")
choice=input("choose A/B/C").upper()
if choice=="B":
  print("correct option")
  score+=1
else:
  print("incorret option")
print()
print("what is the sum of 4444+333+12?")
print("A.4789")
print("B.4777")
print("C.4765")
choice=input("choose A/B/C").upper()
if choice=="A":
  print("correct option")
  score+=1
else:
  print("incorret option")
print()
print("what is 121/11?")
print("A.13")
print("B.12")
print("C.11")
choice=input("choose A/B/C").upper()
if choice=="C":
  print("correct option")
  score+=1
else:
  print("incorret option")
print()
print("thank you for attending my quiz!")
print("your score is ", score)
# Out:
# welcome to my quiz!
#
# how many edges does a cube have?
# A.8
# B.12
# C.16
# choose A/B/C16
# incorret option
#
# what is the sum of 4444+333+12?
# A.4789
# B.4777
# C.4765
# choose A/B/Ca
# correct option
#
# what is 121/11?
# A.13
# B.12
# C.11
# choose A/B/Cc
# correct option
#
# thank you for attending my quiz!
# your score is  2
