# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-class/blob/main/class_1_learning_print.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#learning print
print("hello joses")
print("hello \njoses")
print("hello again joses",end=":0")
print("this wont go on next line")
#math
print("multiply 8 and 12",8*12)
# Out:
# hello joses
# hello
# joses
# hello again joses:0this wont go on next line
# multiply 8 and 12 96
