# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-class/blob/main/Math_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tree1_h=98
tree2_h=94
tree3_h=41
tree4_h=96
tree5_h=11
avg=(tree1_h+tree2_h+tree3_h+tree4_h+tree5_h)/5
print(f"the average height of trees in jacks backyard is {avg}")
# Out:
# the average height of trees in jacks backyard is 68.0

# %%
amount=int(input("what amount do you need?"))
d100=amount//100
d50=(amount%100)//50
d10=((amount %100)%50)//10
print(f"dollar 100 notes {d100}")
print(f"dollar 50 notes {d50}")
print(f"dollar 10 notes {d10}")
# Out:
# what amount do you need?1570
# dollar 100 notes 15
# dollar 50 notes 1
# dollar 10 notes 2

# %%
math=40
science=70
hindi=50
english=60
s=math+science+hindi+english
t=100*4
p=s/t*100
print(f"raj scored {p}%")
# Out:
# raj scored 55.00000000000001%
