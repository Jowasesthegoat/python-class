# %% [markdown]
# <a href="https://colab.research.google.com/github/Jowasesthegoat/python-class/blob/main/data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name="Joses"
print(f"{Name} it's type is {type(Name)}")
age=11
print(f"{age} it's type is {type(age)}")

Height=5.1
print(f"{Height} it's type is {type(Height)}")

likes_spaghetti=True
print(f"{likes_spaghetti} it's type is {type(likes_spaghetti)}")
# Out:
# Joses it's type is <class 'str'>
# 11 it's type is <class 'int'>
# 5.1 it's type is <class 'float'>
# True it's type is <class 'bool'>

# %%
age=11
print(f"the type of age is {type(age)}")
age=str(age)
print(f"the type of is age {type(age)} ")
score=1
score=float(score)
print(f"the type of score is {type(score)}")
print(score)
mathscore=int(input("Joses Mathscore"))
print(mathscore + 10)
# Out:
# the type of age is <class 'int'>
# the type of is age <class 'str'>
# the type of score is <class 'float'>
# 1.0
# Joses Mathscore90
# 100

# %%
s="codingal"
print(s[: :-1])
# Out:
# lagnidoc
